# %%
import tensorflow as tf
print(tf.__version__)

# !pip install -q tensorflow-datasets
# Out:
# 2.3.0

# %%
import tensorflow_datasets as tfds
imdb, info = tfds.load("imdb_reviews", with_info=True, as_supervised=True)
# Out:
# Downloading and preparing dataset imdb_reviews/plain_text/1.0.0 (download: 80.23 MiB, generated: Unknown size, total: 80.23 MiB) to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Completed...', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Size...', max=1.0, style=ProgressSty…
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# /usr/local/lib/python3.6/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# /usr/local/lib/python3.6/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#
# /usr/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1280         """Send a complete request to the server."""
# -> 1281         self._send_request(method, url, body, headers, encode_chunked)
#    1282
#
# /usr/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1326             body = _encode(body, 'body')
# -> 1327         self.endheaders(body, encode_chunked=encode_chunked)
#    1328
#
# /usr/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1275             raise CannotSendHeader()
# -> 1276         self._send_output(message_body, encode_chunked=encode_chunked)
#    1277
#
# /usr/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1041         del self._buffer[:]
# -> 1042         self.send(msg)
#    1043
#
# /usr/lib/python3.6/http/client.py in send(self, data)
#     979             if self.auto_open:
# --> 980                 self.connect()
#     981             else:
#
# /usr/local/lib/python3.6/dist-packages/urllib3/connection.py in connect(self)
#     180     def connect(self):
# --> 181         conn = self._new_conn()
#     182         self._prepare_conn(conn)
#
# /usr/local/lib/python3.6/dist-packages/urllib3/connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f411bf951d0>: Failed to establish a new connection: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# /usr/local/lib/python3.6/dist-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     398         if new_retry.is_exhausted():
# --> 399             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     400
#
# MaxRetryError: HTTPConnectionPool(host='ai.stanford.edu', port=80): Max retries exceeded with url: /~amaas/data/sentiment/aclImdb_v1.tar.gz (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f411bf951d0>: Failed to establish a new connection: [Errno 111] Connection refused',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-2-4c7477c665ce> in <module>()
#       1 import tensorflow_datasets as tfds
# ----> 2 imdb, info = tfds.load("imdb_reviews", with_info=True, as_supervised=True)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_datasets/core/load.py in load(name, split, data_dir, batch_size, shuffle_files, download, as_supervised, decoders, read_config, with_info, builder_kwargs, download_and_prepare_kwargs, as_dataset_kwargs, try_gcs)
#     342   if download:
#     343     download_and_prepare_kwargs = download_and_prepare_kwargs or {}
# --> 344     dbuilder.download_and_prepare(**download_and_prepare_kwargs)
#     345
#     346   if as_dataset_kwargs is None:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_datasets/core/dataset_builder.py in download_and_prepare(self, download_dir, download_config)
#     385           self._download_and_prepare(
#     386               dl_manager=dl_manager,
# --> 387               download_config=download_config)
#     388
#     389           # NOTE: If modifying the lines below to put additional information in
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_datasets/core/dataset_builder.py in _download_and_prepare(self, dl_manager, download_config)
#    1022     super(GeneratorBasedBuilder, self)._download_and_prepare(
#    1023         dl_manager=dl_manager,
# -> 1024         max_examples_per_split=download_config.max_examples_per_split,
#    1025     )
#    1026
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_datasets/core/dataset_builder.py in _download_and_prepare(self, dl_manager, **prepare_split_kwargs)
#     960         prepare_split_kwargs)
#     961     for split_generator in self._split_generators(
# --> 962         dl_manager, **split_generators_kwargs):
#     963       if str(split_generator.split_info.name).lower() == "all":
#     964         raise ValueError(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_datasets/text/imdb.py in _split_generators(self, dl_manager)
#     120
#     121   def _split_generators(self, dl_manager):
# --> 122     arch_path = dl_manager.download(_DOWNLOAD_URL)
#     123     archive = lambda: dl_manager.iter_archive(arch_path)
#     124
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_datasets/core/download/download_manager.py in download(self, url_or_urls)
#     543     # Add progress bar to follow the download state
#     544     with self._downloader.tqdm():
# --> 545       return _map_promise(self._download, url_or_urls)
#     546
#     547   def iter_archive(self, resource):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_datasets/core/download/download_manager.py in _map_promise(map_fn, all_inputs)
#     634   """Map the function into each element and resolve the promise."""
#     635   all_promises = tf.nest.map_structure(map_fn, all_inputs)  # Apply the function
# --> 636   res = tf.nest.map_structure(lambda p: p.get(), all_promises)  # Wait promises
#     637   return res
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     633
#     634   return pack_sequence_as(
# --> 635       structure[0], [func(*x) for x in entries],
#     636       expand_composites=expand_composites)
#     637
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     633
#     634   return pack_sequence_as(
# --> 635       structure[0], [func(*x) for x in entries],
#     636       expand_composites=expand_composites)
#     637
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_datasets/core/download/download_manager.py in <lambda>(p)
#     634   """Map the function into each element and resolve the promise."""
#     635   all_promises = tf.nest.map_structure(map_fn, all_inputs)  # Apply the function
# --> 636   res = tf.nest.map_structure(lambda p: p.get(), all_promises)  # Wait promises
#     637   return res
#
# /usr/local/lib/python3.6/dist-packages/promise/promise.py in get(self, timeout)
#     510         target = self._target()
#     511         self._wait(timeout or DEFAULT_TIMEOUT)
# --> 512         return self._target_settled_value(_raise=True)
#     513
#     514     def _target_settled_value(self, _raise=False):
#
# /usr/local/lib/python3.6/dist-packages/promise/promise.py in _target_settled_value(self, _raise)
#     514     def _target_settled_value(self, _raise=False):
#     515         # type: (bool) -> Any
# --> 516         return self._target()._settled_value(_raise)
#     517
#     518     _value = _reason = _target_settled_value
#
# /usr/local/lib/python3.6/dist-packages/promise/promise.py in _settled_value(self, _raise)
#     224             if _raise:
#     225                 raise_val = self._fulfillment_handler0
# --> 226                 reraise(type(raise_val), raise_val, self._traceback)
#     227             return self._fulfillment_handler0
#     228
#
# /usr/local/lib/python3.6/dist-packages/six.py in reraise(tp, value, tb)
#     701             if value.__traceback__ is not tb:
#     702                 raise value.with_traceback(tb)
# --> 703             raise value
#     704         finally:
#     705             value = None
#
# /usr/local/lib/python3.6/dist-packages/promise/promise.py in handle_future_result(future)
#     842         # type: (Any) -> None
#     843         try:
# --> 844             resolve(future.result())
#     845         except Exception as e:
#     846             tb = exc_info()[2]
#
# /usr/lib/python3.6/concurrent/futures/_base.py in result(self, timeout)
#     423                 raise CancelledError()
#     424             elif self._state == FINISHED:
# --> 425                 return self.__get_result()
#     426
#     427             self._condition.wait(timeout)
#
# /usr/lib/python3.6/concurrent/futures/_base.py in __get_result(self)
#     382     def __get_result(self):
#     383         if self._exception:
# --> 384             raise self._exception
#     385         else:
#     386             return self._result
#
# /usr/lib/python3.6/concurrent/futures/thread.py in run(self)
#      54
#      55         try:
# ---> 56             result = self.fn(*self.args, **self.kwargs)
#      57         except BaseException as exc:
#      58             self.future.set_exception(exc)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_datasets/core/download/downloader.py in _sync_download(self, url, destination_path)
#     182       pass
#     183
# --> 184     with _open_url(url) as (response, iter_content):
#     185       fname = _get_filename(response)
#     186       path = os.path.join(destination_path, fname)
#
# /usr/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_datasets/core/download/downloader.py in _open_with_requests(url)
#     228     if _DRIVE_URL.match(url):
#     229       url = _get_drive_url(url, session)
# --> 230     with session.get(url, stream=True) as response:
#     231       _assert_status(response)
#     232       yield (response, response.iter_content(chunk_size=io.DEFAULT_BUFFER_SIZE))
#
# /usr/local/lib/python3.6/dist-packages/requests/sessions.py in get(self, url, **kwargs)
#     541
#     542         kwargs.setdefault('allow_redirects', True)
# --> 543         return self.request('GET', url, **kwargs)
#     544
#     545     def options(self, url, **kwargs):
#
# /usr/local/lib/python3.6/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /usr/local/lib/python3.6/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.6/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='ai.stanford.edu', port=80): Max retries exceeded with url: /~amaas/data/sentiment/aclImdb_v1.tar.gz (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f411bf951d0>: Failed to establish a new connection: [Errno 111] Connection refused',))

# %%
import numpy as np

train_data, test_data = imdb['train'], imdb['test']

training_sentences = []
training_labels = []

testing_sentences = []
testing_labels = []

# str(s.tonumpy()) is needed in Python3 instead of just s.numpy()
for s,l in train_data:
  training_sentences.append(s.numpy().decode('utf8'))
  training_labels.append(l.numpy())
  
for s,l in test_data:
  testing_sentences.append(s.numpy().decode('utf8'))
  testing_labels.append(l.numpy())
  
training_labels_final = np.array(training_labels)
testing_labels_final = np.array(testing_labels)

# %%
len(training_sentences), len(testing_sentences)

# %%
vocab_size = 10000
embedding_dim = 16
max_length = 120
trunc_type='post'
oov_tok = "<OOV>"


from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(training_sentences)
padded = pad_sequences(sequences,maxlen=max_length, truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences,maxlen=max_length)

# %%
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

def decode_review(text):
    return ' '.join([reverse_word_index.get(i, '?') for i in text])

print(decode_review(padded[3]))
print(training_sentences[3])
# Out:
# ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? this is the kind of film for a snowy sunday afternoon when the rest of the world can go ahead with its own business as you <OOV> into a big arm chair and <OOV> for a couple of hours wonderful performances from cher and nicolas cage as always gently row the plot along there are no <OOV> to cross no dangerous waters just a warm and witty <OOV> through new york life at its best a family film in every sense and one that deserves the praise it received
# This is the kind of film for a snowy Sunday afternoon when the rest of the world can go ahead with its own business as you descend into a big arm-chair and mellow for a couple of hours. Wonderful performances from Cher and Nicolas Cage (as always) gently row the plot along. There are no rapids to cross, no dangerous waters, just a warm and witty paddle through New York life at its best. A family film in every sense and one that deserves the praise it received.

# %%
reverse_word_index
# Out:
# {1: '<OOV>',
#  2: 'the',
#  3: 'and',
#  4: 'a',
#  5: 'of',
#  6: 'to',
#  7: 'is',
#  8: 'br',
#  9: 'in',
#  10: 'it',
#  11: 'i',
#  12: 'this',
#  13: 'that',
#  14: 'was',
#  15: 'as',
#  16: 'for',
#  17: 'with',
#  18: 'movie',
#  19: 'but',
#  20: 'film',
#  21: 'on',
#  22: 'not',
#  23: 'you',
#  24: 'are',
#  25: 'his',
#  26: 'have',
#  27: 'he',
#  28: 'be',
#  29: 'one',
#  30: 'all',
#  31: 'at',
#  32: 'by',
#  33: 'an',
#  34: 'they',
#  35: 'who',
#  36: 'so',
#  37: 'from',
#  38: 'like',
#  39: 'her',
#  40: 'or',
#  41: 'just',
#  42: 'about',
#  43: "it's",
#  44: 'out',
#  45: 'if',
#  46: 'has',
#  47: 'some',
#  48: 'there',
#  49: 'what',
#  50: 'good',
#  51: 'more',
#  52: 'when',
#  53: 'very',
#  54: 'up',
#  55: 'no',
#  56: 'time',
#  57: 'she',
#  58: 'even',
#  59: 'my',
#  60: 'would',
#  61: 'which',
#  62: 'only',
#  63: 'story',
#  64: 'really',
#  65: 'see',
#  66: 'their',
#  67: 'had',
#  68: 'can',
#  69: 'were',
#  70: 'me',
#  71: 'well',
#  72: 'than',
#  73: 'we',
#  74: 'much',
#  75: 'been',
#  76: 'bad',
#  77: 'get',
#  78: 'will',
#  79: 'do',
#  80: 'also',
#  81: 'into',
#  82: 'people',
#  83: 'other',
#  84: 'first',
#  85: 'great',
#  86: 'because',
#  87: 'how',
#  88: 'him',
#  89: 'most',
#  90: "don't",
#  91: 'made',
#  92: 'its',
#  93: 'then',
#  94: 'way',
#  95: 'make',
#  96: 'them',
#  97: 'too',
#  98: 'could',
#  99: 'any',
#  100: 'movies',
#  101: 'after',
#  102: 'think',
#  103: 'characters',
#  104: 'watch',
#  105: 'two',
#  106: 'films',
#  107: 'character',
#  108: 'seen',
#  109: 'many',
#  110: 'being',
#  111: 'life',
#  112: 'plot',
#  113: 'never',
#  114: 'acting',
#  115: 'little',
#  116: 'best',
#  117: 'love',
#  118: 'over',
#  119: 'where',
#  120: 'did',
#  121: 'show',
#  122: 'know',
#  123: 'off',
#  124: 'ever',
#  125: 'does',
#  126: 'better',
#  127: 'your',
#  128: 'end',
#  129: 'still',
#  130: 'man',
#  131: 'here',
#  132: 'these',
#  133: 'say',
#  134: 'scene',
#  135: 'while',
#  136: 'why',
#  137: 'scenes',
#  138: 'go',
#  139: 'such',
#  140: 'something',
#  141: 'through',
#  142: 'should',
#  143: 'back',
#  144: "i'm",
#  145: 'real',
#  146: 'those',
#  147: 'watching',
#  148: 'now',
#  149: 'though',
#  150: "doesn't",
#  151: 'years',
#  152: 'old',
#  153: 'thing',
#  154: 'actors',
#  155: 'work',
#  156: '10',
#  157: 'before',
#  158: 'another',
#  159: "didn't",
#  160: 'new',
#  161: 'funny',
#  162: 'nothing',
#  163: 'actually',
#  164: 'makes',
#  165: 'director',
#  166: 'look',
#  167: 'find',
#  168: 'going',
#  169: 'few',
#  170: 'same',
#  171: 'part',
#  172: 'again',
#  173: 'every',
#  174: 'lot',
#  175: 'cast',
#  176: 'us',
#  177: 'quite',
#  178: 'down',
#  179: 'want',
#  180: 'world',
#  181: 'things',
#  182: 'pretty',
#  183: 'young',
#  184: 'seems',
#  185: 'around',
#  186: 'got',
#  187: 'horror',
#  188: 'however',
#  189: "can't",
#  190: 'fact',
#  191: 'take',
#  192: 'big',
#  193: 'enough',
#  194: 'long',
#  195: 'thought',
#  196: "that's",
#  197: 'both',
#  198: 'between',
#  199: 'series',
#  200: 'give',
#  201: 'may',
#  202: 'original',
#  203: 'own',
#  204: 'action',
#  205: "i've",
#  206: 'right',
#  207: 'without',
#  208: 'always',
#  209: 'times',
#  210: 'comedy',
#  211: 'point',
#  212: 'gets',
#  213: 'must',
#  214: 'come',
#  215: 'role',
#  216: "isn't",
#  217: 'saw',
#  218: 'almost',
#  219: 'interesting',
#  220: 'least',
#  221: 'family',
#  222: 'done',
#  223: "there's",
#  224: 'whole',
#  225: 'bit',
#  226: 'music',
#  227: 'script',
#  228: 'far',
#  229: 'making',
#  230: 'anything',
#  231: 'guy',
#  232: 'minutes',
#  233: 'feel',
#  234: 'last',
#  235: 'since',
#  236: 'might',
#  237: 'performance',
#  238: "he's",
#  239: '2',
#  240: 'probably',
#  241: 'kind',
#  242: 'am',
#  243: 'away',
#  244: 'yet',
#  245: 'rather',
#  246: 'tv',
#  247: 'worst',
#  248: 'girl',
#  249: 'day',
#  250: 'sure',
#  251: 'fun',
#  252: 'hard',
#  253: 'woman',
#  254: 'played',
#  255: 'each',
#  256: 'found',
#  257: 'anyone',
#  258: 'having',
#  259: 'especially',
#  260: 'although',
#  261: 'our',
#  262: 'course',
#  263: 'believe',
#  264: 'comes',
#  265: 'looking',
#  266: 'screen',
#  267: 'trying',
#  268: 'set',
#  269: 'goes',
#  270: 'looks',
#  271: 'place',
#  272: 'book',
#  273: 'different',
#  274: 'put',
#  275: 'ending',
#  276: 'money',
#  277: 'maybe',
#  278: 'once',
#  279: 'sense',
#  280: 'reason',
#  281: 'true',
#  282: 'actor',
#  283: 'everything',
#  284: "wasn't",
#  285: 'shows',
#  286: 'dvd',
#  287: 'three',
#  288: 'worth',
#  289: 'year',
#  290: 'job',
#  291: 'main',
#  292: 'someone',
#  293: 'together',
#  294: 'watched',
#  295: 'play',
#  296: 'american',
#  297: 'plays',
#  298: '1',
#  299: 'said',
#  300: 'effects',
#  301: 'later',
#  302: 'takes',
#  303: 'instead',
#  304: 'seem',
#  305: 'beautiful',
#  306: 'john',
#  307: 'himself',
#  308: 'version',
#  309: 'audience',
#  310: 'high',
#  311: 'house',
#  312: 'night',
#  313: 'during',
#  314: 'everyone',
#  315: 'left',
#  316: 'special',
#  317: 'seeing',
#  318: 'half',
#  319: 'excellent',
#  320: 'wife',
#  321: 'star',
#  322: 'shot',
#  323: 'war',
#  324: 'idea',
#  325: 'nice',
#  326: 'black',
#  327: 'less',
#  328: 'mind',
#  329: 'simply',
#  330: 'read',
#  331: 'second',
#  332: 'else',
#  333: "you're",
#  334: 'father',
#  335: 'fan',
#  336: 'help',
#  337: 'poor',
#  338: 'completely',
#  339: 'death',
#  340: '3',
#  341: 'used',
#  342: 'home',
#  343: 'either',
#  344: 'short',
#  345: 'line',
#  346: 'given',
#  347: 'men',
#  348: 'top',
#  349: 'dead',
#  350: 'budget',
#  351: 'try',
#  352: 'performances',
#  353: 'wrong',
#  354: 'classic',
#  355: 'boring',
#  356: 'enjoy',
#  357: 'need',
#  358: 'rest',
#  359: 'use',
#  360: 'hollywood',
#  361: 'kids',
#  362: 'low',
#  363: 'production',
#  364: 'until',
#  365: 'along',
#  366: 'full',
#  367: 'friends',
#  368: 'camera',
#  369: 'truly',
#  370: 'women',
#  371: 'awful',
#  372: 'video',
#  373: 'next',
#  374: 'tell',
#  375: 'remember',
#  376: 'couple',
#  377: 'stupid',
#  378: 'start',
#  379: 'stars',
#  380: 'perhaps',
#  381: 'mean',
#  382: 'sex',
#  383: 'came',
#  384: 'recommend',
#  385: 'let',
#  386: 'moments',
#  387: 'wonderful',
#  388: 'episode',
#  389: 'understand',
#  390: 'small',
#  391: 'face',
#  392: 'terrible',
#  393: 'school',
#  394: 'playing',
#  395: 'getting',
#  396: 'written',
#  397: 'often',
#  398: 'doing',
#  399: 'keep',
#  400: 'early',
#  401: 'name',
#  402: 'perfect',
#  403: 'style',
#  404: 'human',
#  405: 'definitely',
#  406: 'others',
#  407: 'gives',
#  408: 'itself',
#  409: 'lines',
#  410: 'live',
#  411: 'become',
#  412: 'person',
#  413: 'dialogue',
#  414: 'lost',
#  415: 'finally',
#  416: 'piece',
#  417: 'head',
#  418: 'case',
#  419: 'felt',
#  420: 'yes',
#  421: 'liked',
#  422: 'supposed',
#  423: 'title',
#  424: "couldn't",
#  425: 'absolutely',
#  426: 'white',
#  427: 'against',
#  428: 'boy',
#  429: 'picture',
#  430: 'sort',
#  431: 'worse',
#  432: 'certainly',
#  433: 'went',
#  434: 'entire',
#  435: 'cinema',
#  436: 'waste',
#  437: 'problem',
#  438: 'hope',
#  439: "she's",
#  440: 'entertaining',
#  441: 'mr',
#  442: 'overall',
#  443: 'evil',
#  444: 'called',
#  445: 'loved',
#  446: 'based',
#  447: 'oh',
#  448: 'several',
#  449: 'fans',
#  450: 'mother',
#  451: 'drama',
#  452: 'beginning',
#  453: 'killer',
#  454: 'lives',
#  455: '5',
#  456: 'direction',
#  457: 'care',
#  458: 'becomes',
#  459: 'already',
#  460: 'laugh',
#  461: 'example',
#  462: 'friend',
#  463: 'dark',
#  464: 'despite',
#  465: 'under',
#  466: 'seemed',
#  467: 'throughout',
#  468: '4',
#  469: 'turn',
#  470: 'unfortunately',
#  471: 'wanted',
#  472: "i'd",
#  473: '\x96',
#  474: 'children',
#  475: 'final',
#  476: 'fine',
#  477: 'history',
#  478: 'amazing',
#  479: 'sound',
#  480: 'guess',
#  481: 'heart',
#  482: 'totally',
#  483: 'humor',
#  484: 'lead',
#  485: 'writing',
#  486: 'michael',
#  487: 'quality',
#  488: "you'll",
#  489: 'close',
#  490: 'son',
#  491: 'wants',
#  492: 'guys',
#  493: 'works',
#  494: 'behind',
#  495: 'tries',
#  496: 'art',
#  497: 'side',
#  498: 'game',
#  499: 'past',
#  500: 'able',
#  501: 'b',
#  502: 'days',
#  503: 'turns',
#  504: "they're",
#  505: 'child',
#  506: 'hand',
#  507: 'flick',
#  508: 'enjoyed',
#  509: 'act',
#  510: 'genre',
#  511: 'town',
#  512: 'favorite',
#  513: 'soon',
#  514: 'kill',
#  515: 'starts',
#  516: 'sometimes',
#  517: 'gave',
#  518: 'car',
#  519: 'run',
#  520: 'late',
#  521: 'eyes',
#  522: 'etc',
#  523: 'actress',
#  524: 'directed',
#  525: 'horrible',
#  526: "won't",
#  527: 'brilliant',
#  528: 'viewer',
#  529: 'parts',
#  530: 'themselves',
#  531: 'self',
#  532: 'hour',
#  533: 'expect',
#  534: 'thinking',
#  535: 'stories',
#  536: 'stuff',
#  537: 'girls',
#  538: 'obviously',
#  539: 'blood',
#  540: 'decent',
#  541: 'city',
#  542: 'voice',
#  543: 'highly',
#  544: 'myself',
#  545: 'feeling',
#  546: 'fight',
#  547: 'except',
#  548: 'slow',
#  549: 'matter',
#  550: 'type',
#  551: 'anyway',
#  552: 'kid',
#  553: 'roles',
#  554: 'killed',
#  555: 'heard',
#  556: 'age',
#  557: 'says',
#  558: 'god',
#  559: 'moment',
#  560: 'took',
#  561: 'leave',
#  562: 'writer',
#  563: 'strong',
#  564: 'cannot',
#  565: 'violence',
#  566: 'police',
#  567: 'hit',
#  568: 'stop',
#  569: 'happens',
#  570: 'particularly',
#  571: 'known',
#  572: 'happened',
#  573: 'involved',
#  574: 'extremely',
#  575: 'daughter',
#  576: 'obvious',
#  577: 'told',
#  578: 'chance',
#  579: 'living',
#  580: 'coming',
#  581: 'lack',
#  582: 'experience',
#  583: 'alone',
#  584: 'including',
#  585: "wouldn't",
#  586: 'murder',
#  587: 'attempt',
#  588: 's',
#  589: 'james',
#  590: 'please',
#  591: 'happen',
#  592: 'wonder',
#  593: 'crap',
#  594: 'ago',
#  595: "film's",
#  596: 'brother',
#  597: 'gore',
#  598: 'complete',
#  599: 'none',
#  600: 'interest',
#  601: 'score',
#  602: 'group',
#  603: 'cut',
#  604: 'simple',
#  605: 'save',
#  606: 'ok',
#  607: 'hell',
#  608: 'looked',
#  609: 'number',
#  610: 'career',
#  611: 'song',
#  612: 'possible',
#  613: 'seriously',
#  614: 'annoying',
#  615: 'shown',
#  616: 'exactly',
#  617: 'sad',
#  618: 'running',
#  619: 'musical',
#  620: 'serious',
#  621: 'yourself',
#  622: 'taken',
#  623: 'released',
#  624: 'whose',
#  625: 'david',
#  626: 'cinematography',
#  627: 'scary',
#  628: 'ends',
#  629: 'usually',
#  630: 'hero',
#  631: 'english',
#  632: 'hours',
#  633: 'reality',
#  634: 'opening',
#  635: "i'll",
#  636: 'today',
#  637: 'light',
#  638: 'across',
#  639: 'jokes',
#  640: 'hilarious',
#  641: 'somewhat',
#  642: 'usual',
#  643: 'ridiculous',
#  644: 'body',
#  645: 'cool',
#  646: 'started',
#  647: 'level',
#  648: 'view',
#  649: 'relationship',
#  650: 'change',
#  651: 'opinion',
#  652: 'happy',
#  653: 'middle',
#  654: 'taking',
#  655: 'wish',
#  656: 'finds',
#  657: 'husband',
#  658: 'order',
#  659: 'saying',
#  660: 'talking',
#  661: 'shots',
#  662: 'ones',
#  663: 'documentary',
#  664: 'huge',
#  665: 'novel',
#  666: 'mostly',
#  667: 'female',
#  668: 'robert',
#  669: 'power',
#  670: 'episodes',
#  671: 'room',
#  672: 'important',
#  673: 'rating',
#  674: 'talent',
#  675: 'five',
#  676: 'major',
#  677: 'turned',
#  678: 'strange',
#  679: 'word',
#  680: 'modern',
#  681: 'call',
#  682: 'apparently',
#  683: 'disappointed',
#  684: 'single',
#  685: 'events',
#  686: 'due',
#  687: 'four',
#  688: 'songs',
#  689: 'basically',
#  690: 'attention',
#  691: '7',
#  692: 'knows',
#  693: 'clearly',
#  694: 'supporting',
#  695: 'knew',
#  696: 'comic',
#  697: 'non',
#  698: 'british',
#  699: 'television',
#  700: 'fast',
#  701: 'earth',
#  702: 'country',
#  703: 'cheap',
#  704: 'class',
#  705: 'future',
#  706: 'silly',
#  707: 'thriller',
#  708: '8',
#  709: 'king',
#  710: 'problems',
#  711: "aren't",
#  712: 'easily',
#  713: 'words',
#  714: 'tells',
#  715: 'miss',
#  716: 'jack',
#  717: 'local',
#  718: 'sequence',
#  719: 'bring',
#  720: 'entertainment',
#  721: 'paul',
#  722: 'beyond',
#  723: 'upon',
#  724: 'whether',
#  725: 'predictable',
#  726: 'moving',
#  727: 'straight',
#  728: 'sets',
#  729: 'similar',
#  730: 'romantic',
#  731: 'review',
#  732: 'oscar',
#  733: 'falls',
#  734: 'mystery',
#  735: 'enjoyable',
#  736: 'needs',
#  737: 'rock',
#  738: 'appears',
#  739: 'talk',
#  740: 'george',
#  741: 'giving',
#  742: 'eye',
#  743: 'within',
#  744: 'richard',
#  745: 'ten',
#  746: 'animation',
#  747: 'message',
#  748: 'near',
#  749: 'theater',
#  750: 'above',
#  751: 'dull',
#  752: 'nearly',
#  753: 'sequel',
#  754: 'theme',
#  755: 'points',
#  756: "'",
#  757: 'stand',
#  758: 'mention',
#  759: 'lady',
#  760: 'bunch',
#  761: 'add',
#  762: 'feels',
#  763: 'herself',
#  764: 'release',
#  765: 'red',
#  766: 'team',
#  767: 'storyline',
#  768: 'surprised',
#  769: 'ways',
#  770: 'named',
#  771: 'using',
#  772: "haven't",
#  773: 'lots',
#  774: 'easy',
#  775: 'fantastic',
#  776: 'begins',
#  777: 'actual',
#  778: 'working',
#  779: 'effort',
#  780: 'york',
#  781: 'die',
#  782: 'hate',
#  783: 'french',
#  784: 'tale',
#  785: 'minute',
#  786: 'stay',
#  787: '9',
#  788: 'clear',
#  789: 'feature',
#  790: 'elements',
#  791: 'among',
#  792: 'follow',
#  793: 're',
#  794: 'comments',
#  795: 'viewers',
#  796: 'avoid',
#  797: 'sister',
#  798: 'typical',
#  799: 'showing',
#  800: 'editing',
#  801: "what's",
#  802: 'famous',
#  803: 'tried',
#  804: 'sorry',
#  805: 'fall',
#  806: 'dialog',
#  807: 'check',
#  808: 'period',
#  809: 'form',
#  810: 'season',
#  811: 'certain',
#  812: 'filmed',
#  813: 'weak',
#  814: 'soundtrack',
#  815: 'means',
#  816: 'material',
#  817: 'buy',
#  818: 'somehow',
#  819: 'realistic',
#  820: 'figure',
#  821: 'crime',
#  822: 'gone',
#  823: 'doubt',
#  824: 'peter',
#  825: 'tom',
#  826: 'kept',
#  827: 'viewing',
#  828: 't',
#  829: 'general',
#  830: 'leads',
#  831: 'greatest',
#  832: 'space',
#  833: 'lame',
#  834: 'suspense',
#  835: 'dance',
#  836: 'brought',
#  837: 'imagine',
#  838: 'third',
#  839: 'atmosphere',
#  840: 'hear',
#  841: 'particular',
#  842: 'sequences',
#  843: 'whatever',
#  844: 'parents',
#  845: 'move',
#  846: 'lee',
#  847: 'indeed',
#  848: 'rent',
#  849: 'de',
#  850: 'eventually',
#  851: 'learn',
#  852: 'note',
#  853: 'wait',
#  854: 'deal',
#  855: 'forget',
#  856: 'reviews',
#  857: 'average',
#  858: 'japanese',
#  859: 'sexual',
#  860: 'poorly',
#  861: 'okay',
#  862: 'premise',
#  863: 'zombie',
#  864: 'surprise',
#  865: 'believable',
#  866: 'stage',
#  867: 'sit',
#  868: 'possibly',
#  869: "who's",
#  870: 'decided',
#  871: 'expected',
#  872: "you've",
#  873: 'subject',
#  874: 'nature',
#  875: 'became',
#  876: 'difficult',
#  877: 'free',
#  878: 'killing',
#  879: 'screenplay',
#  880: 'truth',
#  881: 'romance',
#  882: 'dr',
#  883: 'nor',
#  884: 'reading',
#  885: 'needed',
#  886: 'question',
#  887: 'leaves',
#  888: 'street',
#  889: '20',
#  890: 'meets',
#  891: 'hot',
#  892: 'unless',
#  893: 'begin',
#  894: 'baby',
#  895: 'superb',
#  896: 'credits',
#  897: 'otherwise',
#  898: 'imdb',
#  899: 'write',
#  900: 'shame',
#  901: "let's",
#  902: 'situation',
#  903: 'dramatic',
#  904: 'memorable',
#  905: 'directors',
#  906: 'earlier',
#  907: 'badly',
#  908: 'disney',
#  909: 'meet',
#  910: 'open',
#  911: 'dog',
#  912: 'male',
#  913: 'weird',
#  914: 'joe',
#  915: 'acted',
#  916: 'forced',
#  917: 'emotional',
#  918: 'sci',
#  919: 'laughs',
#  920: 'older',
#  921: 'realize',
#  922: 'fi',
#  923: 'dream',
#  924: 'society',
#  925: 'interested',
#  926: 'writers',
#  927: 'comment',
#  928: 'forward',
#  929: 'footage',
#  930: 'crazy',
#  931: 'deep',
#  932: 'whom',
#  933: 'sounds',
#  934: 'beauty',
#  935: 'america',
#  936: 'plus',
#  937: 'fantasy',
#  938: 'directing',
#  939: 'keeps',
#  940: 'development',
#  941: 'ask',
#  942: 'features',
#  943: 'air',
#  944: 'quickly',
#  945: 'mess',
#  946: 'creepy',
#  947: 'perfectly',
#  948: 'towards',
#  949: 'mark',
#  950: 'worked',
#  951: 'box',
#  952: 'cheesy',
#  953: 'unique',
#  954: 'setting',
#  955: 'hands',
#  956: 'plenty',
#  957: 'brings',
#  958: 'previous',
#  959: 'result',
#  960: 'e',
#  961: 'effect',
#  962: 'total',
#  963: 'personal',
#  964: 'incredibly',
#  965: 'rate',
#  966: 'fire',
#  967: 'monster',
#  968: 'business',
#  969: 'leading',
#  970: 'apart',
#  971: 'casting',
#  972: 'admit',
#  973: 'appear',
#  974: 'joke',
#  975: 'background',
#  976: 'powerful',
#  977: 'telling',
#  978: 'meant',
#  979: 'girlfriend',
#  980: 'christmas',
#  981: 'present',
#  982: 'hardly',
#  983: 'potential',
#  984: 'battle',
#  985: 'create',
#  986: 'bill',
#  987: 'break',
#  988: 'pay',
#  989: 'masterpiece',
#  990: 'dumb',
#  991: 'return',
#  992: 'political',
#  993: 'gay',
#  994: 'fails',
#  995: 'fighting',
#  996: 'various',
#  997: 'era',
#  998: 'portrayed',
#  999: 'secret',
#  1000: 'cop',
#  ...}

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 120, 16)           160000
# _________________________________________________________________
# flatten (Flatten)            (None, 1920)              0
# _________________________________________________________________
# dense (Dense)                (None, 6)                 11526
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 171,533
# Trainable params: 171,533
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 10
model.fit(padded, training_labels_final, epochs=num_epochs, validation_data=(testing_padded, testing_labels_final))
# Out:
# Epoch 1/10
# 782/782 [==============================] - 5s 6ms/step - loss: 0.4926 - accuracy: 0.7456 - val_loss: 0.3421 - val_accuracy: 0.8530
# Epoch 2/10
# 782/782 [==============================] - 5s 6ms/step - loss: 0.2448 - accuracy: 0.9049 - val_loss: 0.3614 - val_accuracy: 0.8425
# Epoch 3/10
# 782/782 [==============================] - 5s 6ms/step - loss: 0.1039 - accuracy: 0.9705 - val_loss: 0.4416 - val_accuracy: 0.8261
# Epoch 4/10
# 782/782 [==============================] - 5s 6ms/step - loss: 0.0305 - accuracy: 0.9956 - val_loss: 0.5134 - val_accuracy: 0.8289
# Epoch 5/10
# 782/782 [==============================] - 5s 6ms/step - loss: 0.0132 - accuracy: 0.9982 - val_loss: 0.5836 - val_accuracy: 0.8277
# Epoch 6/10
# 782/782 [==============================] - 5s 6ms/step - loss: 0.0071 - accuracy: 0.9990 - val_loss: 0.6270 - val_accuracy: 0.8246
# Epoch 7/10
# 782/782 [==============================] - 5s 6ms/step - loss: 0.0027 - accuracy: 0.9996 - val_loss: 0.6871 - val_accuracy: 0.8231
# Epoch 8/10
# 782/782 [==============================] - 5s 6ms/step - loss: 7.4013e-04 - accuracy: 1.0000 - val_loss: 0.7360 - val_accuracy: 0.8246
# Epoch 9/10
# 782/782 [==============================] - 5s 6ms/step - loss: 3.5500e-04 - accuracy: 1.0000 - val_loss: 0.7757 - val_accuracy: 0.8254
# Epoch 10/10
# 782/782 [==============================] - 5s 6ms/step - loss: 1.9173e-04 - accuracy: 1.0000 - val_loss: 0.8133 - val_accuracy: 0.8251

# %%
e = model.layers[0]
weights = e.get_weights()[0]
print(weights.shape) # shape: (vocab_size, embedding_dim)
# Out:
# (10000, 16)
